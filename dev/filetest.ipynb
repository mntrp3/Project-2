# %%
import os

# %%
import os.path

# %%
start = os.getcwd()

# %%
start
# Out:
# 'C:\\Users\\Wreedles\\Desktop\\Project-2\\dev'

# %%
path = os.listdir()

# %%
path
# Out:
# ['.ipynb_checkpoints',
#  'app.py',
#  'data',
#  'filetest.ipynb',
#  'test.ipynb',
#  'test2.ipynb']

# %%
os.chdir("C:/Users/Wreedles/Desktop/data")

# %%
new = os.getcwd()

# %%
new
# Out:
# 'C:\\Users\\Wreedles\\Desktop\\data'

# %%
path = os.listdir()

# %%
path
# Out:
# ['OldLWX', 'runningArchive', 'runningArchive.zip']

# %%
new.replace("\\","/")
# Out:
# 'C:/Users/Wreedles/Desktop/data'

# %%
structure = os.walk(new, topdown=True, onerror=None, followlinks=False)

# %%
struct_list = []
for item in structure:
    struct_list.append(list(item))

# %%
len(struct_list)
# Out:
# 990

# %%
struct_list
# Out:
# [['C:\\Users\\Wreedles\\Desktop\\data', ['AKQ', 'CTP', 'LWX', 'PHI'], []],
#  ['C:\\Users\\Wreedles\\Desktop\\data\\AKQ',
#   ['100_122',
#    '103_122',
#    '35_95',
#    '36_90',
#    '37_81',
#    '37_86',
#    '38_100',
#    '38_72',
#    '38_77',
#    '39_68',
#    '39_95',
#    '40_86',
#    '40_91',
#    '41_105',
#    '41_77',
#    '41_82',
#    '42_100',
#    '42_68',
#    '42_73',
#    '43_91',
#    '43_96',
#    '44_82',
#    '44_87',
#    '45_101',
#    '45_105',
#    '45_73',
#    '45_78',
#    '46_69',
#    '46_96',
#    '47_87',
#    '47_92',
#    '48_105',
#    '48_78',
#    '48_83',
#    '49_101',
#    '49_74',
#    '49_97',
#    '50_69',
#    '50_89',
#    '50_90',
#    '50_91',
#    '50_92',
#    '50_93',
#    '50_94',
#    '50_95',
#    '50_96',
#    '50_97',
#    '51_83',
#    '51_88',
#    '51_89',
#    '51_90',
#    '51_91',
#    '51_92',
#    '51_93',
#    '51_94',
#    '51_95',
#    '51_96',
#    '51_97',
#    '52_101',
#    '52_74',
#    '52_79',
# ...

# %%
for item in struct_list:
    os.chdir(item[0])

# %%
for dirpath, dirnames, filenames in os.walk(new):
    for filename in [f for f in filenames if f.endswith(".json")]:
        print(os.path.join(dirpath, filename)[len(new)+1:])
# Out:
# AKQ\100_122\18_03_15_20.json
# AKQ\100_122\18_03_15_21.json
# AKQ\100_122\18_03_15_22.json
# AKQ\100_122\18_03_15_23.json
# AKQ\100_122\18_03_16_00.json
# AKQ\100_122\18_03_16_01.json
# AKQ\100_122\18_03_16_02.json
# AKQ\100_122\18_03_16_03.json
# AKQ\100_122\18_03_16_04.json
# AKQ\100_122\18_03_16_05.json
# AKQ\100_122\18_03_16_06.json
# AKQ\100_122\18_03_16_07.json
# AKQ\100_122\18_03_16_08.json
# AKQ\100_122\18_03_16_09.json
# AKQ\100_122\18_03_16_10.json
# AKQ\100_122\18_03_16_11.json
# AKQ\100_122\18_03_16_12.json
# AKQ\100_122\18_03_16_13.json
# AKQ\100_122\18_03_16_14.json
# AKQ\100_122\18_03_16_15.json
# AKQ\100_122\18_03_16_16.json
# AKQ\100_122\18_03_16_17.json
# AKQ\100_122\18_03_16_18.json
# AKQ\100_122\18_03_16_19.json
# AKQ\100_122\18_03_16_20.json
# AKQ\100_122\18_03_16_21.json
# AKQ\100_122\18_03_16_22.json
# AKQ\100_122\18_03_16_23.json
# AKQ\103_122\18_03_15_20.json
# AKQ\103_122\18_03_15_21.json
# AKQ\103_122\18_03_15_22.json
# AKQ\103_122\18_03_15_23.json
# ...
