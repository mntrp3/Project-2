# %%
import ijson

# %%
filename = "./data/18_03_16_06.json"

# %%
with open(filename, 'r') as f:
    gridObjects = ijson.items(f, 'gridData.properties')
    gridColumns = list(gridObjects)

# %%
with open(filename, 'r') as f:
    hourlyObjects = ijson.items(f, 'hourlyData.properties')
    hourlyColumns = list(hourlyObjects)

# %%
with open(filename, 'r') as f:
    forecastObjects = ijson.items(f, 'forecastData.properties')
    forecastColumns = list(forecastObjects)

# %%
forecastColumns
# Out:
# [{'elevation': {'unitCode': 'unit:m', 'value': Decimal('182.88')},
#   'forecastGenerator': 'BaselineForecastGenerator',
#   'generatedAt': '2018-03-16T11:10:46+00:00',
#   'periods': [{'detailedForecast': 'A chance of snow showers before 11am. Mostly sunny, with a high near 42. Northwest wind 12 to 17 mph, with gusts as high as 26 mph. Chance of precipitation is 60%. New snow accumulation of less than half an inch possible.',
#     'endTime': '2018-03-16T18:00:00-04:00',
#     'icon': 'https://api.weather.gov/icons/land/day/snow,60/sct?size=medium',
#     'isDaytime': True,
#     'name': 'Today',
#     'number': 1,
#     'shortForecast': 'Chance Snow Showers then Mostly Sunny',
#     'startTime': '2018-03-16T07:00:00-04:00',
#     'temperature': 42,
#     'temperatureTrend': None,
#     'temperatureUnit': 'F',
#     'windDirection': 'NW',
#     'windSpeed': '12 to 17 mph'},
# ...

# %%
gridColumns
# Out:
# [{'@id': 'https://api.weather.gov/gridpoints/LWX/37,89',
#   '@type': 'wx:Gridpoint',
#   'apparentTemperature': {'sourceUnit': 'F',
#    'uom': 'unit:degC',
#    'values': [{'validTime': '2018-03-16T04:00:00+00:00/PT2H',
#      'value': Decimal('-2.2222222222222')},
#     {'validTime': '2018-03-16T06:00:00+00:00/PT1H',
#      'value': Decimal('-3.3333333333333')},
#     {'validTime': '2018-03-16T07:00:00+00:00/PT1H',
#      'value': Decimal('-3.8888888888889')},
#     {'validTime': '2018-03-16T08:00:00+00:00/PT1H', 'value': -5},
#     {'validTime': '2018-03-16T09:00:00+00:00/PT1H',
#      'value': Decimal('-6.1111111111111')},
#     {'validTime': '2018-03-16T10:00:00+00:00/PT1H',
#      'value': Decimal('-4.4444444444445')},
#     {'validTime': '2018-03-16T11:00:00+00:00/PT1H',
#      'value': Decimal('-5.5555555555555')},
#     {'validTime': '2018-03-16T12:00:00+00:00/PT2H', 'value': -5},
#     {'validTime': '2018-03-16T14:00:00+00:00/PT2H',
# ...

# %%
hourlyColumns
# Out:
# [{'elevation': {'unitCode': 'unit:m', 'value': Decimal('182.88')},
#   'forecastGenerator': 'HourlyForecastGenerator',
#   'generatedAt': '2018-03-16T11:10:45+00:00',
#   'periods': [{'detailedForecast': '',
#     'endTime': '2018-03-16T08:00:00-04:00',
#     'icon': 'https://api.weather.gov/icons/land/day/snow,60?size=small',
#     'isDaytime': True,
#     'name': '',
#     'number': 1,
#     'shortForecast': 'Chance Snow Showers',
#     'startTime': '2018-03-16T07:00:00-04:00',
#     'temperature': 33,
#     'temperatureTrend': None,
#     'temperatureUnit': 'F',
#     'windDirection': 'NW',
#     'windSpeed': '12 to 15 mph'},
#    {'detailedForecast': '',
#     'endTime': '2018-03-16T09:00:00-04:00',
#     'icon': 'https://api.weather.gov/icons/land/day/snow,60?size=small',
#     'isDaytime': True,
#     'name': '',
#     'number': 2,
#     'shortForecast': 'Chance Snow Showers',
#     'startTime': '2018-03-16T08:00:00-04:00',
#     'temperature': 32,
# ...
